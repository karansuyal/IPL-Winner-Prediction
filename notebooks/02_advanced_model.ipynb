# %%
import joblib

# Check if model exists
import os
if os.path.exists('../models/ipl_advanced_model.pkl'):
    print("✅ Model already saved!")
else:
    # Save the model
    joblib.dump(best_model, '../models/ipl_advanced_model.pkl')
    joblib.dump(le_team_a, '../models/le_team_a.pkl')
    joblib.dump(le_team_b, '../models/le_team_b.pkl')
    joblib.dump(le_venue, '../models/le_venue.pkl')
    joblib.dump(le_toss_winner, '../models/le_toss_winner.pkl')
    joblib.dump(le_toss_decision, '../models/le_toss_decision.pkl')
    joblib.dump(le_winner, '../models/le_winner.pkl')
    print("✅ Model saved!")
# Out:
# ✅ Model already saved!
